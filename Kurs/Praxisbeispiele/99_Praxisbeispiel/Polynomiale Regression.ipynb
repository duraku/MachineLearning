# %%
import pandas as pd

df = pd.read_csv("diamonds.csv")

df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
# Preis auf Grundlage des Gewichts schätzen
X = df[["carat"]].values
Y = df[["price"]].values

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,Y,random_state = 0, test_size = 0.25)

from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)

print(model.score(X_test, y_test))
# Out:
# 0.8506009410929625

# %%
# Preis auf Grundlage der Länge, Breite, Höhe schätzen

X = df[["x","y","z"]].values
Y = df[["price"]].values

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,Y,random_state = 0, test_size = 0.25)

from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)

print(model.score(X_test, y_test))
# Out:
# 0.7834062179737854

# %% [markdown]
# Polynomiale Regression

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
from sklearn.linear_model import LinearRegression

X = df[["x","y","z"]].values
Y = df[["price"]].values

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,Y,random_state = 0, test_size = 0.25)

pf = PolynomialFeatures(degree = 2, include_bias = False)
pf.fit(X_train)

# print(pf.powers_)

# Eckige Klammer geben wir die gewünschten Spalten an
X_train_transformed = pf.transform(X_train)
X_test_transformed = pf.transform(X_test)

from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train_transformed, y_train)

print(model.score(X_test_transformed, y_test))
# Out:
# 0.8658475479746959

# %% [markdown]
# Hot Encoding

# %%
df1 = pd.get_dummies(df, columns = ["cut", "clarity"])
df1
# Out:
#        carat color  depth  table  price     x     y     z  cut_Fair  cut_Good  \
# 0       0.23     E   61.5   55.0    326  3.95  3.98  2.43         0         0
# 1       0.21     E   59.8   61.0    326  3.89  3.84  2.31         0         0
# 2       0.23     E   56.9   65.0    327  4.05  4.07  2.31         0         1
# 3       0.29     I   62.4   58.0    334  4.20  4.23  2.63         0         0
# 4       0.31     J   63.3   58.0    335  4.34  4.35  2.75         0         1
# ...      ...   ...    ...    ...    ...   ...   ...   ...       ...       ...
# 53935   0.72     D   60.8   57.0   2757  5.75  5.76  3.50         0         0
# 53936   0.72     D   63.1   55.0   2757  5.69  5.75  3.61         0         1
# 53937   0.70     D   62.8   60.0   2757  5.66  5.68  3.56         0         0
# 53938   0.86     H   61.0   58.0   2757  6.15  6.12  3.74         0         0
# 53939   0.75     D   62.2   55.0   2757  5.83  5.87  3.64         0         0
#
# ...

# %%
y = df1[["price"]].values
x = df1[["carat","depth","table","x","y","z","cut_Fair", "cut_Good", "cut_Ideal","cut_Premium","clarity_I1","clarity_IF","clarity_SI1","clarity_SI2","clarity_VS1","clarity_VS2","clarity_VVS1" ]].values

from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(x,y,random_state = 0, test_size = 0.25)

from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, Y_train)
print(model.score(X_test, Y_test))
# Out:
# 0.9001489830288528
